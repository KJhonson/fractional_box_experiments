# %% [markdown]
# # 🚀 Complete Jupyter Notebook Tutorial
#
# Welcome to your comprehensive Jupyter Notebook tutorial! This notebook will teach you everything you need to know about using Jupyter in your DOLFINx environment.
#
# ## Table of Contents
# 1. [What is Jupyter?](#what-is-jupyter)
# 2. [Basic Operations](#basic-operations)
# 3. [Cell Types](#cell-types)
# 4. [Keyboard Shortcuts](#keyboard-shortcuts)
# 5. [Python Programming](#python-programming)
# 6. [Scientific Computing](#scientific-computing)
# 7. [Data Visualization](#data-visualization)
# 8. [DOLFINx Integration](#dolfinx-integration)
# 9. [Best Practices](#best-practices)
# 10. [Advanced Features](#advanced-features)

# %% [markdown]
# ## What is Jupyter?
#
# Jupyter Notebook is an **interactive computing environment** that allows you to:
# - Write and execute code in cells
# - Mix code, text, equations, and visualizations
# - Create reproducible research documents
# - Share your work easily
#
# **Key Benefits:**
# - ✅ Interactive development
# - ✅ Live documentation
# - ✅ Easy sharing and collaboration
# - ✅ Perfect for data science and research
# - ✅ Excellent for prototyping

# %%
# This is a code cell - you can execute Python code here
print("Hello, Jupyter!")

# Variables persist between cells
x = 42
y = 3.16
print(f"x = {x}, y = {y}")
# Out:
# Hello, Jupyter!
# x = 42, y = 3.16

# %%
# Variables from previous cells are available
result = x * y
print(f"x * y = {result}")
# Out:
# x * y = 131.88

# %% [markdown]
# ## Basic Operations & Keyboard Shortcuts
#
# ### Running Cells
# - **Shift + Enter**: Run current cell and move to next
# - **Ctrl + Enter**: Run current cell and stay
# - **Alt + Enter**: Run current cell and insert new cell below
#
# ### Cell Modes
# - **Edit Mode** (green border): You can type in the cell
# - **Command Mode** (blue border): You can use keyboard shortcuts
# - Press **Esc** to enter command mode
# - Press **Enter** to enter edit mode
#
# ### Essential Shortcuts (in Command Mode)
# - `A`: Insert cell above
# - `B`: Insert cell below
# - `DD`: Delete cell (press D twice)
# - `M`: Change to Markdown cell
# - `Y`: Change to Code cell
# - `Z`: Undo cell deletion
# - `Ctrl + S`: Save notebook
